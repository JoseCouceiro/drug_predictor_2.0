# %%
import os
import pandas as pd
import numpy as np
import pubchempy as pcp
from rdkit import Chem
from rdkit.Chem import AllChem, MACCSkeys, Descriptors
from keras.utils import to_categorical
import pickle

# %%
drug_dataset = pd.read_csv(os.path.join('..', 'data', '01_raw', 'drugs_dataset', 'all_drugs_dataset.csv'))

# %%
drug_dataset.head()
# Out:
#          CID  HBondAcceptorCount  HBondDonorCount
# 0      24769                 2.0              0.0  \
# 1  134694070                 9.0              6.0
# 2       5121                 2.0              0.0
# 3    4660557                 1.0              1.0
# 4     122175                 2.0              2.0
#
#                                       IsomericSMILES  MolecularWeight  LogP
# 0                         CN(C)CCCCCCN(C)C.C(CBr)CBr          374.205   NaN  \
# 1  C1CN=C(N1)NC2=C(C3=NC=CN=C3C=C2)Br.[C@@H](C(C(...          442.226   NaN
# 2                     C1CSC2=NC(CN21)C3=CC=C(C=C3)Br          283.187   2.5
# 3                 C1C2CC3CC1CC(C2)C3NC4=CC=C(C=C4)Br          306.247   5.0
# 4                                     CC(CCC(C#C)N)N          126.203  -0.4
#
#    RuleFive MATC_Code_Short                       MATC_Code_Explanation
# 0       1.0               B              Blood and blood forming organs
# 1       0.0               C                       Cardiovascular system
# 2       1.0               J             Antiinfectives for systemic use
# 3       1.0               N                              Nervous system
# 4       1.0               L  Antineoplastic and immunomodulating agents

# %%
drug_dataset_cols = drug_dataset[['CID', 'IsomericSMILES', 'MATC_Code_Short', 'MATC_Code_Explanation']]

# %%
drug_dataset_cols.head()
# Out:
#          CID                                     IsomericSMILES
# 0      24769                         CN(C)CCCCCCN(C)C.C(CBr)CBr  \
# 1  134694070  C1CN=C(N1)NC2=C(C3=NC=CN=C3C=C2)Br.[C@@H](C(C(...
# 2       5121                     C1CSC2=NC(CN21)C3=CC=C(C=C3)Br
# 3    4660557                 C1C2CC3CC1CC(C2)C3NC4=CC=C(C=C4)Br
# 4     122175                                     CC(CCC(C#C)N)N
#
#   MATC_Code_Short                       MATC_Code_Explanation
# 0               B              Blood and blood forming organs
# 1               C                       Cardiovascular system
# 2               J             Antiinfectives for systemic use
# 3               N                              Nervous system
# 4               L  Antineoplastic and immunomodulating agents

# %%
no_drug_dataset = pd.DataFrame({'CID': drug_dataset['CID']+1 ,'MATC_Code_Short': 'ND','MATC_Code_Explanation': 'No Drug'})

# %%
type(no_drug_dataset['CID'][0])
# Out:
# numpy.int64

# %%
def get_smiles(cid):
    str_cid = str(cid)
    try:
        compounds = pcp.get_compounds(str_cid, 'cid')
        
        return(compounds[0].smiles)
    except Exception:
        print(f"Could not retrieve SMILES for CID: {cid}")
        return None
smi = get_smiles(2244)
print(smi)
# Out:
# CC(=O)OC1=CC=CC=C1C(=O)O

# %%
no_drug_dataset['CID']
# Out:
# 0           24770
# 1       134694071
# 2            5122
# 3         4660558
# 4          122176
#           ...
# 9949       121099
# 9950      3034027
# 9951        64940
# 9952        65451
# 9953      9851776
# Name: CID, Length: 9954, dtype: int64

# %%
no_drug_dataset['IsomericSMILES'] = no_drug_dataset['CID'].apply(get_smiles)
# Out:
# Could not retrieve SMILES for CID: 12899070
# Could not retrieve SMILES for CID: 9549214
# Could not retrieve SMILES for CID: 146383
# Could not retrieve SMILES for CID: 5702180
# Could not retrieve SMILES for CID: 134693235
# Could not retrieve SMILES for CID: 122185
# Could not retrieve SMILES for CID: 122032
# Could not retrieve SMILES for CID: 18406187
# Could not retrieve SMILES for CID: 20824
# Could not retrieve SMILES for CID: 54607814
# Could not retrieve SMILES for CID: 517574
# Could not retrieve SMILES for CID: 104788
# Could not retrieve SMILES for CID: 122173046
# Could not retrieve SMILES for CID: 101545480
# Could not retrieve SMILES for CID: 133109137
# Could not retrieve SMILES for CID: 132274086
# Could not retrieve SMILES for CID: 23622963
# Could not retrieve SMILES for CID: 122130147
# Could not retrieve SMILES for CID: 14374
# Could not retrieve SMILES for CID: 5282046
# Could not retrieve SMILES for CID: 5326761
# Could not retrieve SMILES for CID: 5311011
# Could not retrieve SMILES for CID: 11962413
# Could not retrieve SMILES for CID: 11965428
# Could not retrieve SMILES for CID: 11967810
# Could not retrieve SMILES for CID: 11968015
# Could not retrieve SMILES for CID: 11978814
# Could not retrieve SMILES for CID: 11979536
# Could not retrieve SMILES for CID: 11979607
# Could not retrieve SMILES for CID: 11979957
# Could not retrieve SMILES for CID: 11988954
# Could not retrieve SMILES for CID: 11993703
# Could not retrieve SMILES for CID: 11993741
# Could not retrieve SMILES for CID: 12193681
# Could not retrieve SMILES for CID: 12314121
# Could not retrieve SMILES for CID: 12546499
# Could not retrieve SMILES for CID: 12799846
# Could not retrieve SMILES for CID: 12818201
# Could not retrieve SMILES for CID: 12851499
# Could not retrieve SMILES for CID: 12971802
# Could not retrieve SMILES for CID: 12971805
# Could not retrieve SMILES for CID: 12986440
# Could not retrieve SMILES for CID: 13200034
# Could not retrieve SMILES for CID: 13270163
# Could not retrieve SMILES for CID: 13559282
# Could not retrieve SMILES for CID: 14017588
# Could not retrieve SMILES for CID: 14179009
# Could not retrieve SMILES for CID: 14179014
# Could not retrieve SMILES for CID: 14257661
# Could not retrieve SMILES for CID: 14724483
# Could not retrieve SMILES for CID: 15391181
# Could not retrieve SMILES for CID: 15558639
# Could not retrieve SMILES for CID: 15574942
# Could not retrieve SMILES for CID: 15575652
# Could not retrieve SMILES for CID: 15814657
# Could not retrieve SMILES for CID: 15920263
# Could not retrieve SMILES for CID: 15950377
# Could not retrieve SMILES for CID: 15951530
# Could not retrieve SMILES for CID: 15953901
# Could not retrieve SMILES for CID: 15979286
# Could not retrieve SMILES for CID: 15981398
# Could not retrieve SMILES for CID: 16004693
# Could not retrieve SMILES for CID: 16007394
# Could not retrieve SMILES for CID: 16019978
# Could not retrieve SMILES for CID: 16045196
# Could not retrieve SMILES for CID: 16048657
# Could not retrieve SMILES for CID: 16051934
# Could not retrieve SMILES for CID: 16051948
# Could not retrieve SMILES for CID: 16056829
# Could not retrieve SMILES for CID: 16076884
# Could not retrieve SMILES for CID: 16119815
# Could not retrieve SMILES for CID: 16124689
# Could not retrieve SMILES for CID: 16129618
# Could not retrieve SMILES for CID: 16129621
# Could not retrieve SMILES for CID: 16129630
# Could not retrieve SMILES for CID: 16129676
# Could not retrieve SMILES for CID: 16129682
# Could not retrieve SMILES for CID: 16129689
# Could not retrieve SMILES for CID: 16129704
# Could not retrieve SMILES for CID: 16129705
# Could not retrieve SMILES for CID: 16129707
# Could not retrieve SMILES for CID: 16129750
# Could not retrieve SMILES for CID: 46783783
# Could not retrieve SMILES for CID: 46847941
# Could not retrieve SMILES for CID: 46853874
# Could not retrieve SMILES for CID: 46871658
# Could not retrieve SMILES for CID: 46886610
# Could not retrieve SMILES for CID: 46930994
# Could not retrieve SMILES for CID: 49769201
# Could not retrieve SMILES for CID: 49800037
# Could not retrieve SMILES for CID: 49803314
# Could not retrieve SMILES for CID: 49806721
# Could not retrieve SMILES for CID: 49831258
# Could not retrieve SMILES for CID: 49841218
# Could not retrieve SMILES for CID: 49843518
# Could not retrieve SMILES for CID: 49846580
# Could not retrieve SMILES for CID: 49849622
# Could not retrieve SMILES for CID: 50905714
# Could not retrieve SMILES for CID: 90467623
# Could not retrieve SMILES for CID: 136122664
# Could not retrieve SMILES for CID: 136180066
# Could not retrieve SMILES for CID: 136238509
# Could not retrieve SMILES for CID: 136245568
# Could not retrieve SMILES for CID: 136246611
# Could not retrieve SMILES for CID: 136246613
# Could not retrieve SMILES for CID: 136343519
# Could not retrieve SMILES for CID: 136601294
# Could not retrieve SMILES for CID: 136619759
# Could not retrieve SMILES for CID: 136649218
# Could not retrieve SMILES for CID: 136709104
# Could not retrieve SMILES for CID: 137030255
# Could not retrieve SMILES for CID: 137086835
# Could not retrieve SMILES for CID: 137091917
# Could not retrieve SMILES for CID: 137179784
# Could not retrieve SMILES for CID: 137183588

# %%
no_drug_dataset.dropna(inplace=True)

# %%
no_drug_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9839 entries, 0 to 9953
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CID                    9839 non-null   int64
#  1   MATC_Code_Short        9839 non-null   object
#  2   MATC_Code_Explanation  9839 non-null   object
#  3   IsomericSMILES         9839 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 384.3+ KB

# %%
no_drug_dataset.to_csv(os.path.join('..', 'data', '01_raw', 'drugs_dataset', 'no_drug_dataset.csv'), index=False)

# %%
no_drug_dataset[no_drug_dataset['IsomericSMILES'].isnull()]
# Out:
# Empty DataFrame
# Columns: [CID, MATC_Code_Short, MATC_Code_Explanation, IsomericSMILES]
# Index: []

# %%
no_drug_dataset['IsomericSMILES'].isnull().sum()
# Out:
# 0

# %%
no_drug_dataset.head()
# Out:
#          CID MATC_Code_Short MATC_Code_Explanation
# 0      24770              ND               No Drug  \
# 1  134694071              ND               No Drug
# 2       5122              ND               No Drug
# 3    4660558              ND               No Drug
# 4     122176              ND               No Drug
#
#                                       IsomericSMILES
# 0  C1=CC(=CC=C1CCC(=O)C2=C(C=C(C=C2O)O)O)O.OP(=O)...
# 1  C[N+](C)(C)CCOP(=O)(OCC1[C@H](C(C(O1)N2C=CC(=N...
# 2                   CCCN(CCC)C1CCC2=C(C=CC(=C2C1)O)F
# 3                   CC1CSC(=NC2(C3CCC(C3)C2(C)C)C)O1
# 4  CC(C)[C@@H](C(=O)N)NC(=O)[C@@H](CCCN=C(N)N)NC(...

# %%
df_final = pd.concat([drug_dataset_cols, no_drug_dataset], ignore_index=True)

# %%
df_final['is_drug'] = (df_final['MATC_Code_Short'] != 'ND').astype(int)

# %%
drugs_dataset_final = df_final.sort_values(by='CID').reset_index(drop=True)

# %%
drugs_dataset_final.head(20)
# Out:
#     CID                                     IsomericSMILES MATC_Code_Short
# 0     1                   CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C               N  \
# 1     2                      CC(=O)OC(CC(=O)O)C[N+](C)(C)C              ND
# 2    72                            C1=CC(=C(C=C1C(=O)O)O)O               L
# 3    73  C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)O)O...              ND
# 4   137                                  C(CC(=O)O)C(=O)CN               L
# 5   138                                      C(CCN)CC(=O)O              ND
# 6   144                  C1=CC2=C(C=C1O)C(=CN2)CC(C(=O)O)N               N
# 7   145                       C(C(C(C(=O)O)O)O)C(=O)C(=O)O              ND
# 8   149               CSCC1C(C(C(O1)N2C=NC3=C2N=CN=C3N)O)O               J
# 9   150                      C(C1C(C(C(O1)N)O)O)OP(=O)(O)O              ND
# 10  164                      C(CC(=C[N+]#N)[O-])C(C(=O)O)N               L
# 11  165                         C(CC(=C[N+]#N)O)C(C(=O)O)N              ND
# 12  174                                             C(CO)O               A
# 13  175                                         CC(=O)[O-]              ND
# 14  176                                            CC(=O)O               S
# 15  177                                               CC=O              ND
# 16  187                               CC(=O)OCC[N+](C)(C)C               S
# 17  188  CC(=O)OC1C(C(C(C(O1)CO)OC2C(C(C(C(O2)CO)O)O)O)O)O              ND
# 18  194  C1=NC2=C(C(=N1)N)N=CN2C3C(C(C(O3)COP(=O)(O)OP(...               B
# 19  195  C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)O)O...              ND
#
#                          MATC_Code_Explanation  is_drug
# 0                               Nervous system        1
# 1                                      No Drug        0
# 2   Antineoplastic and immunomodulating agents        1
# 3                                      No Drug        0
# 4   Antineoplastic and immunomodulating agents        1
# 5                                      No Drug        0
# 6                               Nervous system        1
# 7                                      No Drug        0
# 8              Antiinfectives for systemic use        1
# 9                                      No Drug        0
# 10  Antineoplastic and immunomodulating agents        1
# 11                                     No Drug        0
# 12             Alimentary tract and metabolism        1
# 13                                     No Drug        0
# 14                              Sensory organs        1
# 15                                     No Drug        0
# 16                              Sensory organs        1
# 17                                     No Drug        0
# 18              Blood and blood forming organs        1
# 19                                     No Drug        0

# %%
drugs_dataset_final.to_csv(os.path.join('..', 'data', '01_raw', 'drugs_dataset', 'drugs_dataset_final.csv'), index=False)

# %%
#Function templates

# ======================================================
# Load Kedro-processed drug data
# ======================================================

with open("data/05_model_input/drug_X.pkl", "rb") as f:
    X_drug = pickle.load(f)

with open("data/05_model_input/drug_y_drug.pkl", "rb") as f:
    y_drug = pickle.load(f)

with open("data/05_model_input/drug_y_atc.pkl", "rb") as f:
    y_atc = pickle.load(f)

atc_mapping = pd.read_csv("data/08_reporting/atc_mapping.csv")
n_classes = y_atc.shape[1]

# ======================================================
# Load your non-drug dataset
# ======================================================

non_drug_df = pd.read_csv("data/01_raw/non_drugs_dataset.csv")
print(f"Loaded {len(non_drug_df)} non-drug molecules.")


# ======================================================
# Fingerprint generation (same function as in Kedro)
# ======================================================

def mol_from_smiles(smiles: str):
    try:
        return Chem.MolFromSmiles(smiles)
    except Exception:
        return None


def compute_fingerprints(smiles: str, radius=2, n_bits=2048):
    mol = mol_from_smiles(smiles)
    if mol is None:
        return np.zeros(n_bits + 167 + 1)

    # Morgan fingerprint
    morgan = AllChem.GetMorganFingerprintAsBitVect(mol, radius, nBits=n_bits)
    morgan = np.array(morgan)

    # MACCS keys
    maccs = MACCSkeys.GenMACCSKeys(mol)
    maccs = np.array(list(maccs.ToBitString()), dtype=int)

    # TPSA descriptor
    tpsa = np.array([Descriptors.TPSA(mol)])

    return np.concatenate([morgan, maccs, tpsa])


# ======================================================
# Process non-drugs
# ======================================================

print("Computing fingerprints for non-drugs...")
X_non_drug = np.stack(non_drug_df["IsomericSMILES"].map(compute_fingerprints))
y_non_drug = np.zeros(len(non_drug_df))  # non-drugs labeled 0
y_non_drug_atc = np.zeros((len(non_drug_df), n_classes))  # no ATC class

# ======================================================
# Combine with drug dataset
# ======================================================

X_final = np.vstack([X_drug, X_non_drug])
y_drug_final = np.concatenate([y_drug, y_non_drug])
y_atc_final = np.vstack([y_atc, y_non_drug_atc])

print(f"✅ Final dataset shape: {X_final.shape}")
print(f"   → Drugs: {int(sum(y_drug))}, Non-drugs: {int(len(y_non_drug))}")
print(f"   → ATC classes: {n_classes}")

# ======================================================
# Save combined dataset
# ======================================================

with open("data/05_model_input/drug_non_drug_X.pkl", "wb") as f:
    pickle.dump(X_final, f)

with open("data/05_model_input/drug_non_drug_y_drug.pkl", "wb") as f:
    pickle.dump(y_drug_final, f)

with open("data/05_model_input/drug_non_drug_y_atc.pkl", "wb") as f:
    pickle.dump(y_atc_final, f)

print("💾 Saved combined dataset to data/05_model_input/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 5
#       1 # ======================================================
#       2 # Load Kedro-processed drug data
#       3 # ======================================================
# ----> 5 with open("data/05_model_input/drug_X.pkl", "rb") as f:
#       6     X_drug = pickle.load(f)
#       8 with open("data/05_model_input/drug_y_drug.pkl", "rb") as f:
#
# File c:\Users\josin\anaconda3\envs\kedro-rebuild\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/05_model_input/drug_X.pkl'
